# %% [markdown]
# # Miniproject#3 장소 인식

# %% [markdown]
# ## 1.소개
# 딥러닝 및 컴퓨터비전에서 장소 인식은 아래의 단계를 거쳐서 이뤄집니다.
# 1. 이미지에서 장소를 대표하는 하나의 global descriptor를 추출한다.
# 2. 비교하려는 이미지 간에 global descriptor 사이의 유사도를 비교하여 가장 유사도가 높은 이미지로 장소를 찾아낸다.
#
# 이번 프로젝트는 각자의 방법으로 global descriptor를 비교해 장소인식을 구현하는 것입니다. 예제로 convolutional autoencoder,vgg16의 CNN 구조에 FC레이어를 추가한 모델의 출력으로 global descriptor를 만드는 것입니다.
# 이렇게 만든 같은 장소의 global descriptor들은 이미지를 찍은 시점, 계절, 빛의 세기에 관계없이 유사도가 가장 높아지는 것을 목표로 합니다.
#
# 이번에 사용할 데이터셋은 이미지를 찍은 시점, 빛의 세기는 같지만, 계절이 여름과 가을로 다른 장소 이미지를 사용합니다. 이미지를 직접 가져와서 확인해봅시다.

# %% [markdown]
# ## 2.먼저 구글드라이브와 colab을 연동해봅시다.

# %% [markdown]
# 아래의 코드를 실행하여 이미지를 로드합니다.

# %%
from google.colab import drive
drive.mount('/content/drive/')
import os
if os.getcwd() != '/content/drive/My Drive':
    os.chdir('./drive/My Drive')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
#     Mounted at /content/drive/
# 라는 문구가 나왔다면 성공입니다.아래의 명령어를 실행하여
#
#     /content/drive/My Drive
# 이 나왔는지 확인해주세요

# %%
# !pwd
# Out:
# /content/drive/My Drive

# %% [markdown]
# ## 3.train set으로 이미지와 이름확인하기

# %% [markdown]
# 일단 train set을 모두 가져옵니다. 업로드한 파일 **'place_recognition'**의 압축을 풀고 google drive에 업로드 해야합니다.

# %%
import numpy as np

train_summer_temp = np.load("./place_recognition/summer_train_150.npy")
train_fall_temp = np.load("./place_recognition/fall_train_150.npy")
print("summer image shape is ", train_summer_temp.shape)
print("fall image shape is ", train_fall_temp.shape)
# Out:
# summer image shape is  (3000, 150, 150, 3)
# fall image shape is  (3000, 150, 150, 3)

# %%
train_summer = train_summer_temp[:2900]
train_fall   = train_fall_temp[:2900]
valid_summer = train_summer_temp[2900:3000]
valid_fall   = train_fall_temp[2900:3000]

print("summer image shape is ", train_summer.shape)
print("fall image shape is ", train_fall.shape)

print("Valid summer image shape is ", valid_summer.shape)
print("Valid  fall image shape is ", valid_fall.shape)
# Out:
# summer image shape is  (2900, 150, 150, 3)
# fall image shape is  (2900, 150, 150, 3)
# Valid summer image shape is  (100, 150, 150, 3)
# Valid  fall image shape is  (100, 150, 150, 3)

# %%
import matplotlib.pyplot as plt
import cv2
def draw_place_image(summer_images, fall_images, image_index):
  fig =plt.figure()
  fig.set_size_inches(15,10.5,forward=True)
  rows=1
  cols=2
  if image_index >=2900:    #//수정
    image_index =2899
  #저장된 이미지는 vgg16의 입력 이미지와 같은 BGR채널을 가지는 이미지입니다. 
  #해당이미지를 RGB이미지로 변환하여 확인합니다.
  RGB_summer_image =cv2.cvtColor(summer_images[image_index], cv2.COLOR_BGR2RGB)
  RGB_fall_image =cv2.cvtColor(fall_images[image_index], cv2.COLOR_BGR2RGB)
  ax1 = fig.add_subplot(rows,cols,1)
  ax1.imshow(RGB_summer_image)
  ax1.set_title('Summer Image['+str(image_index)+"]",fontsize=20)
  ax1.axis("off")

  ax2 = fig.add_subplot(rows,cols,2)
  ax2.imshow(RGB_fall_image)
  ax2.set_title('Fall Image['+str(image_index)+"]",fontsize=20)
  ax2.axis("off")

draw_place_image(train_summer, train_fall, 40)

# %% [markdown]
# 오른쪽 이미지가 좀더 가을 계절처럼 보이나요?

# %% [markdown]
# ## 4.불러온 이미지 전처리

# %% [markdown]
# 이제 불러온 이미지를 모델의 입력으로 넣을 수 있게 끔 아래의 과정을 진행해야합니다.
# - 이미지를 BGR이미지로 변환
# - 0과 255 사이에서 0과 1사이의 값으로 변환
#
# 첫 번째인 BGR이미지 변환은 이미되어있고 , 아래의 코드를 실행하여 이미지를 0과 1사이의 값으로 바꿉니다.

# %%
# train_summer = train_summer / 255.0
# train_fall = train_fall/255.0

train_summer_norm = train_summer / 255.0
train_fall_norm   = train_fall   / 255.0
valid_summer_norm = valid_summer / 255.0
valid_fall_norm   = valid_fall   / 255.0

# %% [markdown]
# ## 5.Convolutional Autoencoder(CAE)를 통한 descriptor 추출

# %% [markdown]
# CAE는 입력된 데이터를 압축하는 모델로 데이터의 특징을 추출할 수 있는 기능, 압축에의한 손실, 사람의 개입이 없는 자동학습이라는 특징을 가지고 있습니다. 아래의 링크를 통해서 자세한 정보를 확인할 수 있습니다.
# (https://keraskorea.github.io/posts/2018-10-23-keras_autoencoder/)
#
# 이번 프로젝트에서 사용될 특징은 데이터의 특징을 추출하는 것입니다. ![캡처.PNG](data:image/png;base64,...)

# %% [markdown]
# 위 사진에서 확인할 수 있듯이 Encoder를 통해서 이미지를 특징점을 가지는 global descriptor로 압축하는 것이 가능합니다. 아래의 간단한 모델을 통해서 확인해 보겠습니다.

# %%
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, Flatten, Reshape
from keras.models import Model
from keras import backend as K

input_img = Input(shape=(150, 150, 3))  

x = Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((3, 3), padding='same')(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((5, 5), padding='same')(x)
x = Flatten()(x)
encoded = Dense(200, activation='relu')(x)

# Encoder model
encoder = Model(input_img, encoded)
encoder.summary()

Decoded_img = Input(shape=(200,))
x = Dense(5*5*8)(Decoded_img)
x = Reshape((5,5,8))(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((5, 5))(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((3, 3))(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(3, (3, 3), activation='sigmoid', padding='same')(x)
decoder = Model(Decoded_img, decoded)
decoder.summary()

x = encoder(input_img)
decoder_out = decoder(x)
autoencoder = Model(input_img, decoder_out)
autoencoder.summary()
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy', metrics=["accuracy"] )
# Out:
# Model: "model_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_16 (InputLayer)        [(None, 150, 150, 3)]     0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 150, 150, 16)      448
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 75, 75, 16)        0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 75, 75, 8)         1160
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 25, 25, 8)         0
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 25, 25, 8)         584
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 5, 5, 8)           0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 200)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 200)               40200
# =================================================================
# Total params: 42,392
# Trainable params: 42,392
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_22"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_17 (InputLayer)        [(None, 200)]             0
# _________________________________________________________________
# dense_15 (Dense)             (None, 200)               40200
# _________________________________________________________________
# reshape_7 (Reshape)          (None, 5, 5, 8)           0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 5, 5, 8)           584
# _________________________________________________________________
# up_sampling2d_21 (UpSampling (None, 25, 25, 8)         0
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 25, 25, 8)         584
# _________________________________________________________________
# up_sampling2d_22 (UpSampling (None, 75, 75, 8)         0
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 75, 75, 16)        1168
# _________________________________________________________________
# up_sampling2d_23 (UpSampling (None, 150, 150, 16)      0
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 150, 150, 3)       435
# =================================================================
# Total params: 42,971
# Trainable params: 42,971
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_23"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_16 (InputLayer)        [(None, 150, 150, 3)]     0
# _________________________________________________________________
# model_21 (Functional)        (None, 200)               42392
# _________________________________________________________________
# model_22 (Functional)        (None, 150, 150, 3)       42971
# =================================================================
# Total params: 85,363
# Trainable params: 85,363
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 위에서 생성한 모델을 (summer,fall), (summer,summer), (fall, summer), (fall, fall) 쌍으로 학습을 통해서 global desicriptor를 생성하는 것이 가능합니다.
#
# 아래에서는 (summer, summer)를 조건으로 학습을 진행합니다.

# %%
# # IMG Data to 1dimension vector
# # flatten the 150x150 images into vectors of size 25500

# train_summer_norm_vec = train_summer_norm.reshape((len(train_summer_norm), np.prod(train_summer_norm.shape[1:])))
# train_fall_norm_vec    = train_fall_norm.reshape((len(train_fall_norm), np.prod(train_fall_norm.shape[1:])))

# valid_summer_norm_vec = valid_summer_norm.reshape((len(valid_summer_norm), np.prod(valid_summer_norm.shape[1:])))
# valid_fall_norm_vec    = valid_fall_norm.reshape((len(valid_fall_norm), np.prod(valid_fall_norm.shape[1:])))

# print(valid_summer_norm_vec.shape)
# print(valid_fall_norm_vec.shape)

# %%
autoencoder.fit(train_summer_norm, train_fall_norm, batch_size = 10, epochs= 30, validation_data=(valid_summer_norm,valid_fall_norm))

# valid_summer_norm 
# valid_fall_norm
# Out:
# Epoch 1/30
# 290/290 [==============================] - 5s 12ms/step - loss: 0.7010 - accuracy: 0.1920 - val_loss: 0.6970 - val_accuracy: 0.2994
# Epoch 2/30
# 290/290 [==============================] - 3s 11ms/step - loss: 0.6992 - accuracy: 0.2004 - val_loss: 0.6959 - val_accuracy: 0.3019
# Epoch 3/30
# 290/290 [==============================] - 3s 11ms/step - loss: 0.6977 - accuracy: 0.2072 - val_loss: 0.6951 - val_accuracy: 0.3054
# Epoch 4/30
# 290/290 [==============================] - 3s 11ms/step - loss: 0.6964 - accuracy: 0.2183 - val_loss: 0.6944 - val_accuracy: 0.3103
# Epoch 5/30
# 290/290 [==============================] - 3s 11ms/step - loss: 0.6954 - accuracy: 0.2251 - val_loss: 0.6938 - val_accuracy: 0.3140
# Epoch 6/30
# 290/290 [==============================] - 3s 11ms/step - loss: 0.6945 - accuracy: 0.2329 - val_loss: 0.6934 - val_accuracy: 0.3173
# Epoch 7/30
# 290/290 [==============================] - 3s 11ms/step - loss: 0.6938 - accuracy: 0.2400 - val_loss: 0.6930 - val_accuracy: 0.3206
# Epoch 8/30
# 290/290 [==============================] - 3s 11ms/step - loss: 0.6932 - accuracy: 0.2488 - val_loss: 0.6927 - val_accuracy: 0.3245
# Epoch 9/30
# 290/290 [==============================] - 3s 11ms/step - loss: 0.6926 - accuracy: 0.2579 - val_loss: 0.6924 - val_accuracy: 0.3286
# Epoch 10/30
# 290/290 [==============================] - 3s 11ms/step - loss: 0.6921 - accuracy: 0.2646 - val_loss: 0.6921 - val_accuracy: 0.3304
# Epoch 11/30
# 290/290 [==============================] - 3s 11ms/step - loss: 0.6917 - accuracy: 0.2749 - val_loss: 0.6919 - val_accuracy: 0.3320
# Epoch 12/30
# 290/290 [==============================] - 3s 11ms/step - loss: 0.6913 - accuracy: 0.2812 - val_loss: 0.6917 - val_accuracy: 0.3334
# Epoch 13/30
# 290/290 [==============================] - 3s 11ms/step - loss: 0.6909 - accuracy: 0.2856 - val_loss: 0.6915 - val_accuracy: 0.3346
# Epoch 14/30
# 290/290 [==============================] - 3s 11ms/step - loss: 0.6905 - accuracy: 0.2855 - val_loss: 0.6913 - val_accuracy: 0.3349
# Epoch 15/30
# 290/290 [==============================] - 3s 11ms/step - loss: 0.6902 - accuracy: 0.2840 - val_loss: 0.6911 - val_accuracy: 0.3346
# Epoch 16/30
# 290/290 [==============================] - 3s 11ms/step - loss: 0.6898 - accuracy: 0.2795 - val_loss: 0.6909 - val_accuracy: 0.3344
# Epoch 17/30
# 290/290 [==============================] - 3s 11ms/step - loss: 0.6894 - accuracy: 0.2752 - val_loss: 0.6906 - val_accuracy: 0.3335
# Epoch 18/30
# 290/290 [==============================] - 3s 11ms/step - loss: 0.6890 - accuracy: 0.2661 - val_loss: 0.6904 - val_accuracy: 0.3320
# Epoch 19/30
# 290/290 [==============================] - 3s 11ms/step - loss: 0.6886 - accuracy: 0.2601 - val_loss: 0.6902 - val_accuracy: 0.3300
# Epoch 20/30
# 290/290 [==============================] - 3s 11ms/step - loss: 0.6883 - accuracy: 0.2542 - val_loss: 0.6899 - val_accuracy: 0.3280
# Epoch 21/30
# 290/290 [==============================] - 3s 11ms/step - loss: 0.6878 - accuracy: 0.2446 - val_loss: 0.6896 - val_accuracy: 0.3255
# Epoch 22/30
# 290/290 [==============================] - 3s 11ms/step - loss: 0.6874 - accuracy: 0.2378 - val_loss: 0.6893 - val_accuracy: 0.3228
# Epoch 23/30
# 290/290 [==============================] - 3s 11ms/step - loss: 0.6868 - accuracy: 0.2304 - val_loss: 0.6891 - val_accuracy: 0.3195
# Epoch 24/30
# 290/290 [==============================] - 3s 11ms/step - loss: 0.6863 - accuracy: 0.2234 - val_loss: 0.6887 - val_accuracy: 0.3158
# Epoch 25/30
# 290/290 [==============================] - 3s 11ms/step - loss: 0.6858 - accuracy: 0.2138 - val_loss: 0.6884 - val_accuracy: 0.3119
# Epoch 26/30
# 290/290 [==============================] - 3s 11ms/step - loss: 0.6852 - accuracy: 0.2091 - val_loss: 0.6880 - val_accuracy: 0.3080
# Epoch 27/30
# 290/290 [==============================] - 3s 11ms/step - loss: 0.6846 - accuracy: 0.2018 - val_loss: 0.6877 - val_accuracy: 0.3036
# Epoch 28/30
# 290/290 [==============================] - 3s 11ms/step - loss: 0.6840 - accuracy: 0.1954 - val_loss: 0.6873 - val_accuracy: 0.2988
# Epoch 29/30
# 290/290 [==============================] - 3s 10ms/step - loss: 0.6833 - accuracy: 0.1900 - val_loss: 0.6868 - val_accuracy: 0.2940
# Epoch 30/30
# 290/290 [==============================] - 3s 11ms/step - loss: 0.6825 - accuracy: 0.1843 - val_loss: 0.6864 - val_accuracy: 0.2899

# %% [markdown]
# ### 5-1.descriptor 추출
# 위에서 학습한 autoencder의 encdoer를 이용해서 global descriptor를 추출합니다.

# %%
summer_feature = encoder.predict(train_summer)
fall_feature = encoder.predict(train_fall)

print("summer_feature size = ", summer_feature.shape)
print("fall_feature size = ", fall_feature.shape)
# Out:
# summer_feature size =  (2900, 200)
# fall_feature size =  (2900, 200)

# %% [markdown]
# ### 5-2.similarit matrix(유사도 행렬) 생성
# 유사도 행렬은 두 개의 계절의 이미지에서 서로 유사한 이미지의 유사도를 수식으로 표현한 행렬입니다. 이번 프로젝트에서는 cosine distance를 이용해 결과를 확인할 것입니다.
#
# summer_descriptor = A, fall_descriptor = B
#
# cosine distance = ( A * B) / (||A|| ||B||)

# %%
def cosine_distance(a, b):
    return abs(np.dot(a, b) / (np.linalg.norm(a) * (np.linalg.norm(b))))

# %% [markdown]
# 위에서 생성한 cosine distance를 이용해 각가의 summer 이미지와 fall 이미지 사이의 유사도를 구하고 matrix로 생성합니다. 0~1 사이의 값으로 균등하게 하기위해서 scaling을 적용합니다.

# %%
def similarity_matrix(a,b):
  w_len, h_len = a.shape[0], b.shape[0]
  matrix = np.zeros((w_len, h_len))

  for i in range(w_len):
    for j in range(h_len):
      matrix[i][j] = cosine_distance(a[i],b[j])

  return matrix

def scaling(matrix):
  result = (matrix -np.min(matrix))/(np.max(matrix) - np.min(matrix))
  
  return result

# %% [markdown]
# similarity matrix의 크기를 250x250으로 생성하기 위해서 0~250까지의 이미지의 discriptor를 이용합니다. 확인 결과 아래와 같은 heatmap이 출력됩니다.

# %%
import seaborn as sns
summer_feature = summer_feature[:250]
fall_feature = fall_feature[:250]


matrix = similarity_matrix(summer_feature, fall_feature)
matrix = scaling(matrix)

sns.heatmap(matrix)

# %% [markdown]
# 출력된 결과를 확인하면 대각선으로 밝은 선이 생성되는 것을 확인할 수 있습니다. 하지만 유사도의 차이가 확연하게 차이가 나지 않아서 다른 부분에서도 밝은 부분이 나오는 것을 확인할 수 있습니다.

# %% [markdown]
# ### 5-3.Precision-Recall curve, f1_score
# 모델의 성능을 평가하는 지표로 사용되는 방법입니다. 자세한 설명은 아래의 링크를 통해서 확인하시면 됩니다.
# (https://sumniya.tistory.com/26)
#
# GroudTruth와 생성한 similarity matrix를 비교해 평가합니다.
#
# Ground Truth는 대각행렬이기 때문에 np.eye를 통해서 생성합니다. 그 후 아래의 함수를 통해서 Precision-Recall curve를 생성합니다.

# %%
# Precision-Recall function
import sklearn.metrics as metrics

def Precision_Recall(similarity):
  thresholds = [i / 1000 for i in range(1000)]
  matrix_shape = len(matrix)
  GT = np.eye(matrix_shape)
  pr_s = []
  re_s = []
  f1_s = []

  for threshold in thresholds:
    test_matrix = similarity > threshold

    right = np.sum(test_matrix * GT == 1)
    precision = right / np.sum(test_matrix)
    recall = right/ np.sum(GT)
    f1 = 2 * precision*recall/(precision+recall)

    pr_s.append(precision)
    re_s.append(recall)
    f1_s.append(f1)

  return pr_s, re_s, f1_s

# %%
Precision, Recall, F1 = Precision_Recall(matrix)

plt.plot(Recall,Precision,'-r',label="CAE")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Recall-Precision curve")
plt.legend(loc='upper right')
plt.grid()
plt.show()

# %% [markdown]
# 출력 결과 위와 같은 결과를 확인할 수 있습니다. Precision-recall을 통해서 결과를 확인하는 경우, 그래프가 완만하게 감소하며 recall이 커짐에 따라서 precision이 큰 값을 유지하는 경우 좋은 성능을 가진 모델입니다.

# %% [markdown]
# f1_score의 경우 precsion,recall을 이용한 아래와 같은 식을 통한 함수입니다.
#
# f1_score = 2* (Precision * Recall) /(Precision + Recall)
#
# 이중에서 max값을 이용해 결과를 평가하겠습니다.

# %%
# f1_score_function
f1_max = max(F1)
print("f1_max = ", round(f1_max,4))
# Out:
# f1_max =  0.3675

# %% [markdown]
# ## 6.vgg16을 통한 전이학습
# 이번 프로젝트의 목적은 여러분들이 모델을 생성하거나,컴퓨터 비전 기술 등을 이용해 계절이 다른 장소의 위치를 확인하는 것입니다.
# 그러므로 간단한 예시로 vgg16을 통해서 유사도행렬까지만 출력하겠습니다.
#
# 아래의 링크를 통해서 자세하게 확인할 수 있습니다.
#
# https://www.pyimagesearch.com/2020/11/30/siamese-networks-with-keras-tensorflow-and-deep-learning/

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 각각의 계절의 이미지를 쌍으로 묶어서 입력으로 생성합니다. 이미지 쌍을 생성할 때 동일한 위치의 이미지 쌍과 다른 위치의 이미지 쌍을 생성합니다.
#
# ConvNet 자리에 vgg16을 통해 생성한 모델을 이용해서 각각의 이미지의 discriptor을 생성하고 euclidean_distance을 통해서 유사도를 비교합니다.

# %%
import keras
from keras import Model
from keras import models
from keras.layers import *
from keras.optimizers import RMSprop, Adam
import tensorflow as tf

# %% [markdown]
# 먼저 아래의 코드를 이용해 keras에서 제공하는 pretrained vgg16을 불러옵니다.

# %%
from tensorflow.keras.applications.vgg16 import VGG16
vggmodel = VGG16(weights='imagenet', include_top=False, input_shape=(150,150,3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step

# %%
vggmodel.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 150, 150, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 150, 150, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 75, 75, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 75, 75, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 75, 75, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 37, 37, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 37, 37, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 18, 18, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 18, 18, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 9, 9, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 이미 학습된 모델이기 때문에 전체 모델을 학습을 진행할 때 가중치를 고정하기 위해서 아래와 같이 trainable = False로 변경합니다.

# %%
for layers in (vggmodel.layers)[:19]:
    layers.trainable = False

for i, layer in enumerate(vggmodel.layers):
    print(i,":", 'layer name = ',layer.name, "     trainable = ", layer.trainable)
# Out:
# 0 : layer name =  input_1      trainable =  False
# 1 : layer name =  block1_conv1      trainable =  False
# 2 : layer name =  block1_conv2      trainable =  False
# 3 : layer name =  block1_pool      trainable =  False
# 4 : layer name =  block2_conv1      trainable =  False
# 5 : layer name =  block2_conv2      trainable =  False
# 6 : layer name =  block2_pool      trainable =  False
# 7 : layer name =  block3_conv1      trainable =  False
# 8 : layer name =  block3_conv2      trainable =  False
# 9 : layer name =  block3_conv3      trainable =  False
# 10 : layer name =  block3_pool      trainable =  False
# 11 : layer name =  block4_conv1      trainable =  False
# 12 : layer name =  block4_conv2      trainable =  False
# 13 : layer name =  block4_conv3      trainable =  False
# 14 : layer name =  block4_pool      trainable =  False
# 15 : layer name =  block5_conv1      trainable =  False
# 16 : layer name =  block5_conv2      trainable =  False
# 17 : layer name =  block5_conv3      trainable =  False
# 18 : layer name =  block5_pool      trainable =  False

# %% [markdown]
# 모델의 이미지와 동일한 코드를 생성합니다. vgg16을 discriptor 추출기로 사용합니다.
#
# loss를 생성된 discriptor 간의 차이를 euclidean_distance를 이용하기 위해서 아래와 같이 custom_loss를 생성합니다.
#
# make_pair 함수는 각각의 계절의 이미지를 동일한 위치와, 랜덤한 동일하지 않은 위치의 쌍으로 생성합니다.

# %%
from tensorflow.keras.layers import Input, Dropout, Dense, Flatten
from tensorflow.keras.models import Model
import tensorflow.keras.backend as K

def build_siamese_model(inputShape, embeddingDim=100):      # Siamese Network란 -> 
  inputs = Input(inputShape)
  x = vggmodel(inputs)
  x = Flatten()(x)
  x = Dense(4096, activation='relu', input_dim=4 * 4 * 512)(x)
  x = Dropout(0.5)(x)
  outputs = Dense(100)(x)
  model = Model(inputs,outputs)
  
  return model

def euclidean_distance(vectors):
  (featsA, featsB) = vectors

  sumSquared = K.sum(K.square(featsA- featsB), axis=1, keepdims=True)

  return K.sqrt(K.maximum(sumSquared, K.epsilon()))

def make_pairs(summer, fall, Mode=0):

  pairImages = []
  pairLabels = []

  numPlace = np.arange(len(summer))

  for idx in numPlace:
    currentImage = summer[idx]
    posImage = fall[idx]
    
    pairImages.append([currentImage,posImage])
    pairLabels.append([1])                        # 동일위치

  if Mode == 1:
    for idx in numPlace:
      currentImage = summer[idx]

      for num in range(3):
        negIdx = np.where(numPlace != idx)[0]
        negImage = fall[np.random.choice(negIdx)]
        pairImages.append([currentImage,negImage])
        pairLabels.append([0])                    # 다른위치

  return (np.array(pairImages), np.array(pairLabels))

# %%
from tensorflow.keras.layers import Lambda,Input, Dropout, Dense, Flatten
from tensorflow.keras.models import Model
imgA = Input(shape=(150,150,3))
imgB = Input(shape=(150,150,3))
#descriptorExtractor라는 모델 객체를 만든다.
descriptorExtractor = build_siamese_model((150,150,3))
#이제 해당 모델의 출력으로 각 global descriptor를 출력한다.
descsA = descriptorExtractor(imgA)
descsB = descriptorExtractor(imgB)

#람다(lamda)레이어를 통해서, descriptor 사이의 유클리드 거리를 구한다.
distance = Lambda(euclidean_distance)([descsA,descsB])
#이제 출력을 sigmoid를 사용하여 0과 1사이의 출력이 되도록한다.
outputs = Dense(1, activation='sigmoid')(distance)

#최종적으로 입력과 출력을 등록하여 모델 객체를 생성한다.
final_model = Model(inputs=[imgA, imgB], outputs=outputs)

# %% [markdown]
# ![샴sim.PNG](data:image/png;base64,...)

# %% [markdown]
# 모델을 이용해 결과를 확인한 경우 CAE보다 더 명확한 결과가 생성되는 것을 확인할 수 있습니다.

# %% [markdown]
# # 7.각자의 모델, 또는 방법을 이용한 장소 인식
# 이제 여러분만의 장소 인식 모델을 생성해 결과를 평가하겠습니다.
#
# 기한 : 5.24 ~ 6.6
# (추가제출 기한은 6시간을 추가로 드리겠습니다. 단, 감점이 있을 것입니다.)
#
# 평가 방법: f1_score을 통해서 결과를 확인할 것입니다.
# 여러분들은 각자의 방법으로 descriptor를 추출해서 similarit matrix를 생성해서 보내주시면됩니다.
# test_set으로 사용될 데이터 셋은 마감일 2일 전에 업로드하겠습니다. 단, Ground_truth가 대각선이 아닌 랜덤하게 섞여있는 데이터셋입니다. 출력 결과가 대각선이 아니게 나올 것입니다.
#
#
#
#
# 최종 제출본은 'similarity_matrix.npy', 'MiniProj#3.ipynb', 프로젝트 보고서를 압축한 '이름_학번.zip'를 업로드하시면 됩니다.

# %%
from google.colab import drive
drive.mount('/content/drive/')
import os
if os.getcwd() != '/content/drive/My Drive':
    os.chdir('./drive/My Drive')
# Out:
# Mounted at /content/drive/

# %%
import numpy as np

train_summer_temp = np.load("./place_recognition/summer_train_150.npy")
train_fall_temp = np.load("./place_recognition/fall_train_150.npy")
print("summer image shape is ", train_summer_temp.shape)
print("fall image shape is ", train_fall_temp.shape)

train_summer = train_summer_temp[:2900]
train_fall   = train_fall_temp[:2900]
valid_summer = train_summer_temp[2900:3000]
valid_fall   = train_fall_temp[2900:3000]

print("summer image shape is ", train_summer.shape)
print("fall image shape is ", train_fall.shape)

print("Valid summer image shape is ", valid_summer.shape)
print("Valid  fall image shape is ", valid_fall.shape)

# train_summer = train_summer / 255.0
# train_fall = train_fall/255.0

train_summer_norm = train_summer / 255.0
train_fall_norm   = train_fall   / 255.0
valid_summer_norm = valid_summer / 255.0
valid_fall_norm   = valid_fall   / 255.0
# Out:
# summer image shape is  (3000, 150, 150, 3)
# fall image shape is  (3000, 150, 150, 3)
# summer image shape is  (2900, 150, 150, 3)
# fall image shape is  (2900, 150, 150, 3)
# Valid summer image shape is  (100, 150, 150, 3)
# Valid  fall image shape is  (100, 150, 150, 3)

# %%
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, Flatten, Reshape, Dropout, BatchNormalization, Activation
from keras.models import Model
from keras import backend as K

input_img = Input(shape=(150, 150, 3))  

x = Conv2D(32, (3, 3), padding='same')(input_img)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling2D((2, 2), padding='same')(x)

x = Conv2D(16, (3, 3), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling2D((3, 3), padding='same')(x)

x = Flatten()(x)
encoded = Dense(2500, activation='relu')(x)


# Encoder model
encoder = Model(input_img, encoded)
encoder.summary()

Decoded_img = Input(shape=(2500,))   # Z
x = Dense(5*5*32)(Decoded_img)
x = Reshape((5,5,32))(x)
x = UpSampling2D((5, 5))(x)
x = Conv2D(8, (3, 3), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = UpSampling2D((3, 3))(x)

x = Conv2D(16, (3, 3), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = UpSampling2D((2, 2))(x)

decoded = Conv2D(3, (3, 3), activation='softmax', padding='same')(x)
decoder = Model(Decoded_img, decoded)
decoder.summary()

x = encoder(input_img)
decoder_out = decoder(x)
autoencoder = Model(input_img, decoder_out)
autoencoder.summary()
autoencoder.compile(optimizer='adam', loss='binary_crossentropy', metrics=["accuracy"] )
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 150, 150, 32)      896
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 150, 150, 32)      128
# _________________________________________________________________
# activation_4 (Activation)    (None, 150, 150, 32)      0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 75, 75, 16)        4624
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 75, 75, 16)        64
# _________________________________________________________________
# activation_5 (Activation)    (None, 75, 75, 16)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 25, 25, 16)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 10000)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2500)              25002500
# =================================================================
# Total params: 25,008,212
# Trainable params: 25,008,116
# Non-trainable params: 96
# _________________________________________________________________
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 2500)]            0
# _________________________________________________________________
# dense_3 (Dense)              (None, 800)               2000800
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 5, 5, 32)          0
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 25, 25, 8)         2312
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 25, 25, 8)         32
# _________________________________________________________________
# activation_6 (Activation)    (None, 25, 25, 8)         0
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 75, 75, 8)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 75, 75, 16)        1168
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 75, 75, 16)        64
# _________________________________________________________________
# activation_7 (Activation)    (None, 75, 75, 16)        0
# _________________________________________________________________
# up_sampling2d_5 (UpSampling2 (None, 150, 150, 16)      0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 150, 150, 3)       435
# =================================================================
# Total params: 2,004,811
# Trainable params: 2,004,763
# Non-trainable params: 48
# _________________________________________________________________
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# model_3 (Functional)         (None, 2500)              25008212
# _________________________________________________________________
# model_4 (Functional)         (None, 150, 150, 3)       2004811
# =================================================================
# Total params: 27,013,023
# Trainable params: 27,012,879
# Non-trainable params: 144
# _________________________________________________________________

# %%
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, Flatten, Reshape, Dropout
from keras.models import Model
from keras import backend as K

input_img = Input(shape=(150, 150, 3))  


x = Conv2D(64, (3, 3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((3, 3), padding='same')(x)
x = Flatten()(x)
encoded = Dense(2500, activation='relu')(x)

# Encoder model
encoder = Model(input_img, encoded)
encoder.summary()

Decoded_img = Input(shape=(2500,))   # Z
x = Dense(5*5*64)(Decoded_img)
x = Reshape((5,5,64))(x)
x = UpSampling2D((5, 5))(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((3, 3))(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(3, (3, 3), activation='softmax', padding='same')(x)
decoder = Model(Decoded_img, decoded)
decoder.summary()

x = encoder(input_img)
decoder_out = decoder(x)
autoencoder = Model(input_img, decoder_out)
autoencoder.summary()
autoencoder.compile(optimizer='adam', loss='binary_crossentropy', metrics=["accuracy"] )
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 150, 150, 64)      1792
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 75, 75, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 75, 75, 32)        18464
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 38, 38, 32)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 38, 38, 16)        4624
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 13, 13, 16)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2704)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2500)              6762500
# =================================================================
# Total params: 6,787,380
# Trainable params: 6,787,380
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 2500)]            0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1600)              4001600
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 5, 5, 64)          0
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 25, 25, 64)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 25, 25, 16)        9232
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 75, 75, 16)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 75, 75, 32)        4640
# _________________________________________________________________
# up_sampling2d_5 (UpSampling2 (None, 150, 150, 32)      0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 150, 150, 3)       867
# =================================================================
# Total params: 4,016,339
# Trainable params: 4,016,339
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# model_3 (Functional)         (None, 2500)              6787380
# _________________________________________________________________
# model_4 (Functional)         (None, 150, 150, 3)       4016339
# =================================================================
# Total params: 10,803,719
# Trainable params: 10,803,719
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, Flatten, Reshape, Dropout
from keras.models import Model
from keras import backend as K


input_img = Input(shape=(150, 150, 3))  


x = Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((3, 3), padding='same')(x)
x = Flatten()(x)
encoded = Dense(2500, activation='relu')(x)

# Encoder model
encoder = Model(input_img, encoded)
encoder.summary()

Decoded_img = Input(shape=(2500,))   # Z
x = Dense(5*5*64)(Decoded_img)
x = Reshape((5,5,64))(x)
x = UpSampling2D((5, 5))(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((3, 3))(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(3, (3, 3), activation='sigmoid', padding='same')(x)
decoder = Model(Decoded_img, decoded)
decoder.summary()

x = encoder(input_img)
decoder_out = decoder(x)
autoencoder = Model(input_img, decoder_out)
autoencoder.summary()
autoencoder.compile(optimizer='adam', loss='binary_crossentropy', metrics=["accuracy"] )
# Out:
# Model: "model_27"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_20 (InputLayer)        [(None, 150, 150, 3)]     0
# _________________________________________________________________
# conv2d_49 (Conv2D)           (None, 150, 150, 32)      896
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_50 (Conv2D)           (None, 75, 75, 16)        4624
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 25, 25, 16)        0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 10000)             0
# _________________________________________________________________
# dense_18 (Dense)             (None, 2500)              25002500
# =================================================================
# Total params: 25,008,020
# Trainable params: 25,008,020
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_28"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_21 (InputLayer)        [(None, 2500)]            0
# _________________________________________________________________
# dense_19 (Dense)             (None, 1600)              4001600
# _________________________________________________________________
# reshape_9 (Reshape)          (None, 5, 5, 64)          0
# _________________________________________________________________
# up_sampling2d_27 (UpSampling (None, 25, 25, 64)        0
# _________________________________________________________________
# conv2d_51 (Conv2D)           (None, 25, 25, 16)        9232
# _________________________________________________________________
# up_sampling2d_28 (UpSampling (None, 75, 75, 16)        0
# _________________________________________________________________
# conv2d_52 (Conv2D)           (None, 75, 75, 32)        4640
# _________________________________________________________________
# up_sampling2d_29 (UpSampling (None, 150, 150, 32)      0
# _________________________________________________________________
# conv2d_53 (Conv2D)           (None, 150, 150, 3)       867
# =================================================================
# Total params: 4,016,339
# Trainable params: 4,016,339
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_29"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_20 (InputLayer)        [(None, 150, 150, 3)]     0
# _________________________________________________________________
# model_27 (Functional)        (None, 2500)              25008020
# _________________________________________________________________
# model_28 (Functional)        (None, 150, 150, 3)       4016339
# =================================================================
# Total params: 29,024,359
# Trainable params: 29,024,359
# Non-trainable params: 0
# _________________________________________________________________

# %%
print(train_summer_norm.shape)
print(train_fall_norm.shape)
print(valid_summer_norm.shape)
print(valid_fall_norm.shape)
# Out:
# (2900, 150, 150, 3)
# (2900, 150, 150, 3)
# (100, 150, 150, 3)
# (100, 150, 150, 3)

# %%
autoencoder.fit(train_summer_norm, train_fall_norm, batch_size = 32, epochs= 100, validation_data=(valid_summer_norm,valid_fall_norm))
# Out:
# Epoch 1/100
# 91/91 [==============================] - 7s 64ms/step - loss: 0.6536 - accuracy: 0.5559 - val_loss: 0.6114 - val_accuracy: 0.4262
# Epoch 2/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5359 - accuracy: 0.6543 - val_loss: 0.6435 - val_accuracy: 0.4339
# Epoch 3/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5277 - accuracy: 0.6812 - val_loss: 0.6282 - val_accuracy: 0.4696
# Epoch 4/100
# 91/91 [==============================] - 5s 57ms/step - loss: 0.5253 - accuracy: 0.6930 - val_loss: 0.5853 - val_accuracy: 0.5628
# Epoch 5/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5223 - accuracy: 0.7027 - val_loss: 0.5623 - val_accuracy: 0.6267
# Epoch 6/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5200 - accuracy: 0.7120 - val_loss: 0.5538 - val_accuracy: 0.6299
# Epoch 7/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5167 - accuracy: 0.7175 - val_loss: 0.5634 - val_accuracy: 0.6364
# Epoch 8/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5154 - accuracy: 0.7181 - val_loss: 0.5349 - val_accuracy: 0.6694
# Epoch 9/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5137 - accuracy: 0.7205 - val_loss: 0.5308 - val_accuracy: 0.6826
# Epoch 10/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5138 - accuracy: 0.7239 - val_loss: 0.5292 - val_accuracy: 0.6802
# Epoch 11/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5122 - accuracy: 0.7262 - val_loss: 0.5319 - val_accuracy: 0.6951
# Epoch 12/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5125 - accuracy: 0.7308 - val_loss: 0.5301 - val_accuracy: 0.6913
# Epoch 13/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5122 - accuracy: 0.7287 - val_loss: 0.5257 - val_accuracy: 0.6840
# Epoch 14/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5118 - accuracy: 0.7310 - val_loss: 0.5254 - val_accuracy: 0.6902
# Epoch 15/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5095 - accuracy: 0.7364 - val_loss: 0.5272 - val_accuracy: 0.6937
# Epoch 16/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5117 - accuracy: 0.7332 - val_loss: 0.5255 - val_accuracy: 0.6867
# Epoch 17/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5098 - accuracy: 0.7390 - val_loss: 0.5257 - val_accuracy: 0.7029
# Epoch 18/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5094 - accuracy: 0.7356 - val_loss: 0.5298 - val_accuracy: 0.6969
# Epoch 19/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5102 - accuracy: 0.7382 - val_loss: 0.5287 - val_accuracy: 0.7080
# Epoch 20/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5088 - accuracy: 0.7406 - val_loss: 0.5256 - val_accuracy: 0.7130
# Epoch 21/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5098 - accuracy: 0.7385 - val_loss: 0.5284 - val_accuracy: 0.6975
# Epoch 22/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5080 - accuracy: 0.7412 - val_loss: 0.5269 - val_accuracy: 0.7182
# Epoch 23/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5077 - accuracy: 0.7466 - val_loss: 0.5259 - val_accuracy: 0.6940
# Epoch 24/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5087 - accuracy: 0.7414 - val_loss: 0.5261 - val_accuracy: 0.7128
# Epoch 25/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5086 - accuracy: 0.7468 - val_loss: 0.5252 - val_accuracy: 0.7076
# Epoch 26/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5075 - accuracy: 0.7484 - val_loss: 0.5255 - val_accuracy: 0.7004
# Epoch 27/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5086 - accuracy: 0.7510 - val_loss: 0.5267 - val_accuracy: 0.6993
# Epoch 28/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5077 - accuracy: 0.7532 - val_loss: 0.5249 - val_accuracy: 0.7124
# Epoch 29/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5076 - accuracy: 0.7524 - val_loss: 0.5259 - val_accuracy: 0.7111
# Epoch 30/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5065 - accuracy: 0.7528 - val_loss: 0.5259 - val_accuracy: 0.7063
# Epoch 31/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5073 - accuracy: 0.7533 - val_loss: 0.5259 - val_accuracy: 0.7136
# Epoch 32/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5070 - accuracy: 0.7584 - val_loss: 0.5266 - val_accuracy: 0.6822
# Epoch 33/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5068 - accuracy: 0.7594 - val_loss: 0.5250 - val_accuracy: 0.7087
# Epoch 34/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5066 - accuracy: 0.7558 - val_loss: 0.5274 - val_accuracy: 0.7164
# Epoch 35/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5080 - accuracy: 0.7555 - val_loss: 0.5250 - val_accuracy: 0.7179
# Epoch 36/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5060 - accuracy: 0.7580 - val_loss: 0.5250 - val_accuracy: 0.7219
# Epoch 37/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5054 - accuracy: 0.7605 - val_loss: 0.5253 - val_accuracy: 0.7194
# Epoch 38/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5069 - accuracy: 0.7586 - val_loss: 0.5250 - val_accuracy: 0.7156
# Epoch 39/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5067 - accuracy: 0.7638 - val_loss: 0.5261 - val_accuracy: 0.6855
# Epoch 40/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5073 - accuracy: 0.7642 - val_loss: 0.5252 - val_accuracy: 0.7117
# Epoch 41/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5061 - accuracy: 0.7624 - val_loss: 0.5243 - val_accuracy: 0.7122
# Epoch 42/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5061 - accuracy: 0.7629 - val_loss: 0.5243 - val_accuracy: 0.6970
# Epoch 43/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5075 - accuracy: 0.7592 - val_loss: 0.5259 - val_accuracy: 0.7029
# Epoch 44/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5057 - accuracy: 0.7659 - val_loss: 0.5254 - val_accuracy: 0.6780
# Epoch 45/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5048 - accuracy: 0.7669 - val_loss: 0.5259 - val_accuracy: 0.7190
# Epoch 46/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5057 - accuracy: 0.7640 - val_loss: 0.5249 - val_accuracy: 0.7164
# Epoch 47/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5058 - accuracy: 0.7660 - val_loss: 0.5248 - val_accuracy: 0.7143
# Epoch 48/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5062 - accuracy: 0.7667 - val_loss: 0.5255 - val_accuracy: 0.7206
# Epoch 49/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5044 - accuracy: 0.7654 - val_loss: 0.5257 - val_accuracy: 0.7225
# Epoch 50/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5058 - accuracy: 0.7687 - val_loss: 0.5251 - val_accuracy: 0.7269
# Epoch 51/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5044 - accuracy: 0.7680 - val_loss: 0.5246 - val_accuracy: 0.7115
# Epoch 52/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5062 - accuracy: 0.7683 - val_loss: 0.5255 - val_accuracy: 0.7004
# Epoch 53/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5064 - accuracy: 0.7688 - val_loss: 0.5246 - val_accuracy: 0.7117
# Epoch 54/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5061 - accuracy: 0.7690 - val_loss: 0.5253 - val_accuracy: 0.7051
# Epoch 55/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5068 - accuracy: 0.7675 - val_loss: 0.5249 - val_accuracy: 0.7082
# Epoch 56/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5054 - accuracy: 0.7719 - val_loss: 0.5251 - val_accuracy: 0.7242
# Epoch 57/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5055 - accuracy: 0.7696 - val_loss: 0.5250 - val_accuracy: 0.7220
# Epoch 58/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5051 - accuracy: 0.7670 - val_loss: 0.5249 - val_accuracy: 0.7188
# Epoch 59/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5056 - accuracy: 0.7694 - val_loss: 0.5244 - val_accuracy: 0.7177
# Epoch 60/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5049 - accuracy: 0.7706 - val_loss: 0.5254 - val_accuracy: 0.7306
# Epoch 61/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5062 - accuracy: 0.7687 - val_loss: 0.5248 - val_accuracy: 0.7306
# Epoch 62/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5056 - accuracy: 0.7710 - val_loss: 0.5251 - val_accuracy: 0.7276
# Epoch 63/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5050 - accuracy: 0.7720 - val_loss: 0.5254 - val_accuracy: 0.7330
# Epoch 64/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5054 - accuracy: 0.7710 - val_loss: 0.5250 - val_accuracy: 0.7173
# Epoch 65/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5048 - accuracy: 0.7736 - val_loss: 0.5259 - val_accuracy: 0.7299
# Epoch 66/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5048 - accuracy: 0.7696 - val_loss: 0.5248 - val_accuracy: 0.7194
# Epoch 67/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5058 - accuracy: 0.7753 - val_loss: 0.5259 - val_accuracy: 0.7315
# Epoch 68/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5046 - accuracy: 0.7676 - val_loss: 0.5257 - val_accuracy: 0.7295
# Epoch 69/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5052 - accuracy: 0.7720 - val_loss: 0.5251 - val_accuracy: 0.7177
# Epoch 70/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5054 - accuracy: 0.7705 - val_loss: 0.5254 - val_accuracy: 0.7316
# Epoch 71/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5045 - accuracy: 0.7719 - val_loss: 0.5256 - val_accuracy: 0.7060
# Epoch 72/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5058 - accuracy: 0.7748 - val_loss: 0.5267 - val_accuracy: 0.7190
# Epoch 73/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5040 - accuracy: 0.7750 - val_loss: 0.5247 - val_accuracy: 0.7240
# Epoch 74/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5047 - accuracy: 0.7755 - val_loss: 0.5254 - val_accuracy: 0.7292
# Epoch 75/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5051 - accuracy: 0.7764 - val_loss: 0.5259 - val_accuracy: 0.7062
# Epoch 76/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5052 - accuracy: 0.7734 - val_loss: 0.5263 - val_accuracy: 0.7271
# Epoch 77/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5052 - accuracy: 0.7759 - val_loss: 0.5253 - val_accuracy: 0.7271
# Epoch 78/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5053 - accuracy: 0.7773 - val_loss: 0.5271 - val_accuracy: 0.7290
# Epoch 79/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5056 - accuracy: 0.7726 - val_loss: 0.5250 - val_accuracy: 0.7279
# Epoch 80/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5054 - accuracy: 0.7741 - val_loss: 0.5255 - val_accuracy: 0.7268
# Epoch 81/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5045 - accuracy: 0.7753 - val_loss: 0.5250 - val_accuracy: 0.7178
# Epoch 82/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5047 - accuracy: 0.7756 - val_loss: 0.5251 - val_accuracy: 0.7296
# Epoch 83/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5041 - accuracy: 0.7797 - val_loss: 0.5248 - val_accuracy: 0.7310
# Epoch 84/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5051 - accuracy: 0.7743 - val_loss: 0.5252 - val_accuracy: 0.7285
# Epoch 85/100
# 91/91 [==============================] - 5s 57ms/step - loss: 0.5058 - accuracy: 0.7767 - val_loss: 0.5256 - val_accuracy: 0.7222
# Epoch 86/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5049 - accuracy: 0.7773 - val_loss: 0.5256 - val_accuracy: 0.7284
# Epoch 87/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5052 - accuracy: 0.7755 - val_loss: 0.5249 - val_accuracy: 0.7252
# Epoch 88/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5064 - accuracy: 0.7723 - val_loss: 0.5266 - val_accuracy: 0.7230
# Epoch 89/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5037 - accuracy: 0.7713 - val_loss: 0.5250 - val_accuracy: 0.7292
# Epoch 90/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5046 - accuracy: 0.7730 - val_loss: 0.5247 - val_accuracy: 0.7286
# Epoch 91/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5053 - accuracy: 0.7796 - val_loss: 0.5253 - val_accuracy: 0.7221
# Epoch 92/100
# 91/91 [==============================] - 5s 57ms/step - loss: 0.5049 - accuracy: 0.7788 - val_loss: 0.5252 - val_accuracy: 0.7112
# Epoch 93/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5049 - accuracy: 0.7773 - val_loss: 0.5256 - val_accuracy: 0.7263
# Epoch 94/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5051 - accuracy: 0.7778 - val_loss: 0.5247 - val_accuracy: 0.7172
# Epoch 95/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5056 - accuracy: 0.7791 - val_loss: 0.5248 - val_accuracy: 0.7174
# Epoch 96/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5050 - accuracy: 0.7741 - val_loss: 0.5250 - val_accuracy: 0.7105
# Epoch 97/100
# 91/91 [==============================] - 5s 55ms/step - loss: 0.5043 - accuracy: 0.7784 - val_loss: 0.5253 - val_accuracy: 0.7218
# Epoch 98/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5047 - accuracy: 0.7809 - val_loss: 0.5249 - val_accuracy: 0.7236
# Epoch 99/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5052 - accuracy: 0.7757 - val_loss: 0.5250 - val_accuracy: 0.7255
# Epoch 100/100
# 91/91 [==============================] - 5s 56ms/step - loss: 0.5047 - accuracy: 0.7764 - val_loss: 0.5269 - val_accuracy: 0.7202

# %%
summer_feature = encoder.predict(train_summer)
fall_feature = encoder.predict(train_fall)

print("summer_feature size = ", summer_feature.shape)
print("fall_feature size = ", fall_feature.shape)
# Out:
# summer_feature size =  (2900, 2500)
# fall_feature size =  (2900, 2500)

# %%
def similarity_matrix(a,b):
  w_len, h_len = a.shape[0], b.shape[0]
  matrix = np.zeros((w_len, h_len))

  for i in range(w_len):
    for j in range(h_len):
      matrix[i][j] = cosine_distance(a[i],b[j])

  return matrix

def scaling(matrix):
  result = (matrix -np.min(matrix))/(np.max(matrix) - np.min(matrix))
  
  return result
def cosine_distance(a, b):
    return abs(np.dot(a, b) / (np.linalg.norm(a) * (np.linalg.norm(b))))

# %%
import seaborn as sns
summer_feature = summer_feature[:250]
fall_feature = fall_feature[:250]


matrix = similarity_matrix(summer_feature, fall_feature)
matrix = scaling(matrix)

sns.heatmap(matrix)

# %%
# Precision-Recall function
import sklearn.metrics as metrics
import matplotlib.pyplot as plt 

def Precision_Recall(similarity):
  thresholds = [i / 1000 for i in range(1000)]
  matrix_shape = len(matrix)
  GT = np.eye(matrix_shape)
  pr_s = []
  re_s = []
  f1_s = []

  for threshold in thresholds:
    test_matrix = similarity > threshold

    right = np.sum(test_matrix * GT == 1)
    precision = right / np.sum(test_matrix)
    recall = right/ np.sum(GT)
    f1 = 2 * precision*recall/(precision+recall)

    pr_s.append(precision)
    re_s.append(recall)
    f1_s.append(f1)

  return pr_s, re_s, f1_s

Precision, Recall, F1 = Precision_Recall(matrix)

plt.plot(Recall,Precision,'-r',label="CAE")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Recall-Precision curve")
plt.legend(loc='upper right')
plt.grid()
plt.show()

# %%
# f1_score_function
f1_max = max(F1)
print("f1_max = ", round(f1_max,4))
# Out:
# f1_max =  0.617

# %%
import tensorflow as tf
from keras.models import save_model, load_model
autoencoder.save('./place_recognition/Project3_6.h5')

# %%
# matrix 저장하기
import numpy as np
np.save('./place_recognition/similarity_matrix.npy',matrix)

# %% [markdown]
# Test set 불러오기

# %%
from google.colab import drive
drive.mount('/content/drive/')
import os
if os.getcwd() != '/content/drive/My Drive':
    os.chdir('./drive/My Drive')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import numpy as np

test_summer = np.load("./place_recognition/test_summer.npy")
test_fall = np.load("./place_recognition/test_fall.npy")
print("summer image shape is ", test_summer.shape)
print("fall image shape is ", test_fall.shape)
# Out:
# summer image shape is  (250, 150, 150, 3)
# fall image shape is  (250, 150, 150, 3)

# %%
test_summer_norm = test_summer / 255.0
test_fall_norm   = test_fall   / 255.0

# %%
summer_feature = encoder.predict(test_summer)
fall_feature = encoder.predict(test_fall)

print("summer_feature size = ", summer_feature.shape)
print("fall_feature size = ", fall_feature.shape)
# Out:
# summer_feature size =  (250, 2500)
# fall_feature size =  (250, 2500)

# %%
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, Flatten, Reshape, Dropout, BatchNormalization, Activation
from keras.models import Model
from keras import backend as K

input_img = Input(shape=(150, 150, 3))  

x = Conv2D(32, (3, 3), padding='same')(input_img)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling2D((2, 2), padding='same')(x)

x = Conv2D(16, (3, 3), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling2D((3, 3), padding='same')(x)

x = Flatten()(x)
encoded = Dense(2500, activation='relu')(x)


# Encoder model
encoder = Model(input_img, encoded)
encoder.summary()

Decoded_img = Input(shape=(2500,))   # Z
x = Dense(5*5*32)(Decoded_img)
x = Reshape((5,5,32))(x)
x = UpSampling2D((5, 5))(x)
x = Conv2D(8, (3, 3), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = UpSampling2D((3, 3))(x)

x = Conv2D(16, (3, 3), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = UpSampling2D((2, 2))(x)

decoded = Conv2D(3, (3, 3), activation='softmax', padding='same')(x)
decoder = Model(Decoded_img, decoded)
decoder.summary()

x = encoder(input_img)
decoder_out = decoder(x)
autoencoder = Model(input_img, decoder_out)
autoencoder.summary()
autoencoder.compile(optimizer='adam', loss='binary_crossentropy', metrics=["accuracy"] )
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 150, 150, 32)      896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 150, 150, 32)      128
# _________________________________________________________________
# activation (Activation)      (None, 150, 150, 32)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 16)        4624
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 75, 75, 16)        64
# _________________________________________________________________
# activation_1 (Activation)    (None, 75, 75, 16)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 25, 25, 16)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 10000)             0
# _________________________________________________________________
# dense (Dense)                (None, 2500)              25002500
# =================================================================
# Total params: 25,008,212
# Trainable params: 25,008,116
# Non-trainable params: 96
# _________________________________________________________________
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 2500)]            0
# _________________________________________________________________
# dense_1 (Dense)              (None, 800)               2000800
# _________________________________________________________________
# reshape (Reshape)            (None, 5, 5, 32)          0
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 25, 25, 8)         2312
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 25, 25, 8)         32
# _________________________________________________________________
# activation_2 (Activation)    (None, 25, 25, 8)         0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 75, 75, 8)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 75, 75, 16)        1168
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 75, 75, 16)        64
# _________________________________________________________________
# activation_3 (Activation)    (None, 75, 75, 16)        0
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 150, 150, 16)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 150, 150, 3)       435
# =================================================================
# Total params: 2,004,811
# Trainable params: 2,004,763
# Non-trainable params: 48
# _________________________________________________________________
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# model (Functional)           (None, 2500)              25008212
# _________________________________________________________________
# model_1 (Functional)         (None, 150, 150, 3)       2004811
# =================================================================
# Total params: 27,013,023
# Trainable params: 27,012,879
# Non-trainable params: 144
# _________________________________________________________________

# %%
autoencoder.fit(test_summer_norm, test_fall_norm, batch_size = 32, epochs= 100)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 47s 118ms/step - loss: 0.7651 - accuracy: 0.2102
# Epoch 2/100
# 8/8 [==============================] - 0s 54ms/step - loss: 0.6152 - accuracy: 0.2311
# Epoch 3/100
# 8/8 [==============================] - 0s 52ms/step - loss: 0.5678 - accuracy: 0.2382
# Epoch 4/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.5493 - accuracy: 0.3286
# Epoch 5/100
# 8/8 [==============================] - 0s 54ms/step - loss: 0.5408 - accuracy: 0.4042
# Epoch 6/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.5402 - accuracy: 0.5004
# Epoch 7/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.5375 - accuracy: 0.5851
# Epoch 8/100
# 8/8 [==============================] - 0s 55ms/step - loss: 0.5380 - accuracy: 0.5982
# Epoch 9/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.5321 - accuracy: 0.5864
# Epoch 10/100
# 8/8 [==============================] - 0s 54ms/step - loss: 0.5317 - accuracy: 0.5543
# Epoch 11/100
# 8/8 [==============================] - 0s 54ms/step - loss: 0.5284 - accuracy: 0.5357
# Epoch 12/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.5212 - accuracy: 0.5367
# Epoch 13/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.5181 - accuracy: 0.5521
# Epoch 14/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.5143 - accuracy: 0.5662
# Epoch 15/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.5139 - accuracy: 0.5702
# Epoch 16/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.5135 - accuracy: 0.5773
# Epoch 17/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.5082 - accuracy: 0.5807
# Epoch 18/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.5070 - accuracy: 0.5854
# Epoch 19/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.5051 - accuracy: 0.5936
# Epoch 20/100
# 8/8 [==============================] - 0s 51ms/step - loss: 0.5036 - accuracy: 0.5990
# Epoch 21/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4998 - accuracy: 0.5887
# Epoch 22/100
# 8/8 [==============================] - 0s 54ms/step - loss: 0.5002 - accuracy: 0.6026
# Epoch 23/100
# 8/8 [==============================] - 0s 54ms/step - loss: 0.4984 - accuracy: 0.5969
# Epoch 24/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4983 - accuracy: 0.6050
# Epoch 25/100
# 8/8 [==============================] - 0s 52ms/step - loss: 0.4942 - accuracy: 0.6044
# Epoch 26/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4947 - accuracy: 0.6018
# Epoch 27/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4972 - accuracy: 0.6209
# Epoch 28/100
# 8/8 [==============================] - 0s 52ms/step - loss: 0.4950 - accuracy: 0.5999
# Epoch 29/100
# 8/8 [==============================] - 0s 52ms/step - loss: 0.4935 - accuracy: 0.6125
# Epoch 30/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4973 - accuracy: 0.6079
# Epoch 31/100
# 8/8 [==============================] - 0s 54ms/step - loss: 0.4927 - accuracy: 0.6167
# Epoch 32/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4934 - accuracy: 0.6095
# Epoch 33/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4921 - accuracy: 0.6129
# Epoch 34/100
# 8/8 [==============================] - 0s 52ms/step - loss: 0.4914 - accuracy: 0.6185
# Epoch 35/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4903 - accuracy: 0.6219
# Epoch 36/100
# 8/8 [==============================] - 0s 54ms/step - loss: 0.4909 - accuracy: 0.6217
# Epoch 37/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4918 - accuracy: 0.6200
# Epoch 38/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4925 - accuracy: 0.6154
# Epoch 39/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4909 - accuracy: 0.6174
# Epoch 40/100
# 8/8 [==============================] - 0s 55ms/step - loss: 0.4912 - accuracy: 0.6231
# Epoch 41/100
# 8/8 [==============================] - 0s 55ms/step - loss: 0.4894 - accuracy: 0.6184
# Epoch 42/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4918 - accuracy: 0.6233
# Epoch 43/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4888 - accuracy: 0.6183
# Epoch 44/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4898 - accuracy: 0.6247
# Epoch 45/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4908 - accuracy: 0.6242
# Epoch 46/100
# 8/8 [==============================] - 0s 54ms/step - loss: 0.4891 - accuracy: 0.6223
# Epoch 47/100
# 8/8 [==============================] - 0s 52ms/step - loss: 0.4897 - accuracy: 0.6340
# Epoch 48/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4904 - accuracy: 0.6199
# Epoch 49/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4894 - accuracy: 0.6249
# Epoch 50/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4897 - accuracy: 0.6305
# Epoch 51/100
# 8/8 [==============================] - 0s 52ms/step - loss: 0.4899 - accuracy: 0.6283
# Epoch 52/100
# 8/8 [==============================] - 0s 54ms/step - loss: 0.4876 - accuracy: 0.6339
# Epoch 53/100
# 8/8 [==============================] - 0s 52ms/step - loss: 0.4866 - accuracy: 0.6238
# Epoch 54/100
# 8/8 [==============================] - 0s 52ms/step - loss: 0.4850 - accuracy: 0.6304
# Epoch 55/100
# 8/8 [==============================] - 0s 54ms/step - loss: 0.4863 - accuracy: 0.6333
# Epoch 56/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4899 - accuracy: 0.6353
# Epoch 57/100
# 8/8 [==============================] - 0s 54ms/step - loss: 0.4902 - accuracy: 0.6238
# Epoch 58/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4885 - accuracy: 0.6263
# Epoch 59/100
# 8/8 [==============================] - 0s 54ms/step - loss: 0.4898 - accuracy: 0.6365
# Epoch 60/100
# 8/8 [==============================] - 0s 55ms/step - loss: 0.4867 - accuracy: 0.6270
# Epoch 61/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4887 - accuracy: 0.6332
# Epoch 62/100
# 8/8 [==============================] - 0s 55ms/step - loss: 0.4884 - accuracy: 0.6460
# Epoch 63/100
# 8/8 [==============================] - 0s 54ms/step - loss: 0.4851 - accuracy: 0.6303
# Epoch 64/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4861 - accuracy: 0.6384
# Epoch 65/100
# 8/8 [==============================] - 0s 54ms/step - loss: 0.4883 - accuracy: 0.6393
# Epoch 66/100
# 8/8 [==============================] - 0s 55ms/step - loss: 0.4903 - accuracy: 0.6384
# Epoch 67/100
# 8/8 [==============================] - 0s 55ms/step - loss: 0.4869 - accuracy: 0.6285
# Epoch 68/100
# 8/8 [==============================] - 0s 54ms/step - loss: 0.4846 - accuracy: 0.6463
# Epoch 69/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4862 - accuracy: 0.6444
# Epoch 70/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4858 - accuracy: 0.6436
# Epoch 71/100
# 8/8 [==============================] - 0s 54ms/step - loss: 0.4873 - accuracy: 0.6424
# Epoch 72/100
# 8/8 [==============================] - 0s 55ms/step - loss: 0.4866 - accuracy: 0.6442
# Epoch 73/100
# 8/8 [==============================] - 0s 55ms/step - loss: 0.4847 - accuracy: 0.6422
# Epoch 74/100
# 8/8 [==============================] - 0s 54ms/step - loss: 0.4856 - accuracy: 0.6478
# Epoch 75/100
# 8/8 [==============================] - 0s 55ms/step - loss: 0.4891 - accuracy: 0.6502
# Epoch 76/100
# 8/8 [==============================] - 0s 54ms/step - loss: 0.4878 - accuracy: 0.6404
# Epoch 77/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4863 - accuracy: 0.6496
# Epoch 78/100
# 8/8 [==============================] - 0s 54ms/step - loss: 0.4850 - accuracy: 0.6475
# Epoch 79/100
# 8/8 [==============================] - 0s 54ms/step - loss: 0.4843 - accuracy: 0.6514
# Epoch 80/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4860 - accuracy: 0.6474
# Epoch 81/100
# 8/8 [==============================] - 0s 55ms/step - loss: 0.4855 - accuracy: 0.6420
# Epoch 82/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4860 - accuracy: 0.6473
# Epoch 83/100
# 8/8 [==============================] - 0s 54ms/step - loss: 0.4874 - accuracy: 0.6536
# Epoch 84/100
# 8/8 [==============================] - 0s 54ms/step - loss: 0.4856 - accuracy: 0.6428
# Epoch 85/100
# 8/8 [==============================] - 0s 54ms/step - loss: 0.4852 - accuracy: 0.6485
# Epoch 86/100
# 8/8 [==============================] - 0s 54ms/step - loss: 0.4860 - accuracy: 0.6534
# Epoch 87/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4884 - accuracy: 0.6437
# Epoch 88/100
# 8/8 [==============================] - 0s 54ms/step - loss: 0.4864 - accuracy: 0.6432
# Epoch 89/100
# 8/8 [==============================] - 0s 54ms/step - loss: 0.4870 - accuracy: 0.6580
# Epoch 90/100
# 8/8 [==============================] - 0s 55ms/step - loss: 0.4867 - accuracy: 0.6582
# Epoch 91/100
# 8/8 [==============================] - 0s 54ms/step - loss: 0.4862 - accuracy: 0.6347
# Epoch 92/100
# 8/8 [==============================] - 0s 54ms/step - loss: 0.4887 - accuracy: 0.6521
# Epoch 93/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4860 - accuracy: 0.6478
# Epoch 94/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4840 - accuracy: 0.6507
# Epoch 95/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4861 - accuracy: 0.6602
# Epoch 96/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4851 - accuracy: 0.6457
# Epoch 97/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4869 - accuracy: 0.6545
# Epoch 98/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4864 - accuracy: 0.6459
# Epoch 99/100
# 8/8 [==============================] - 0s 55ms/step - loss: 0.4889 - accuracy: 0.6499
# Epoch 100/100
# 8/8 [==============================] - 0s 53ms/step - loss: 0.4843 - accuracy: 0.6556

# %%
summer_feature = encoder.predict(test_summer)
fall_feature = encoder.predict(test_fall)

print("summer_feature size = ", summer_feature.shape)
print("fall_feature size = ", fall_feature.shape)
# Out:
# summer_feature size =  (250, 2500)
# fall_feature size =  (250, 2500)

# %%
def similarity_matrix(a,b):
  w_len, h_len = a.shape[0], b.shape[0]
  matrix = np.zeros((w_len, h_len))

  for i in range(w_len):
    for j in range(h_len):
      matrix[i][j] = cosine_distance(a[i],b[j])

  return matrix

def scaling(matrix):
  result = (matrix -np.min(matrix))/(np.max(matrix) - np.min(matrix))
  
  return result
def cosine_distance(a, b):
    return abs(np.dot(a, b) / (np.linalg.norm(a) * (np.linalg.norm(b))))

# %%
import seaborn as sns
summer_feature = summer_feature[:250]
fall_feature = fall_feature[:250]


matrix = similarity_matrix(summer_feature, fall_feature)
matrix = scaling(matrix)

sns.heatmap(matrix)

# %%
# Precision-Recall function
import sklearn.metrics as metrics
import matplotlib.pyplot as plt 

def Precision_Recall(similarity):
  thresholds = [i / 1000 for i in range(1000)]
  matrix_shape = len(matrix)
  GT = np.eye(matrix_shape)
  pr_s = []
  re_s = []
  f1_s = []

  for threshold in thresholds:
    test_matrix = similarity > threshold

    right = np.sum(test_matrix * GT == 1)
    precision = right / np.sum(test_matrix)
    recall = right/ np.sum(GT)
    f1 = 2 * precision*recall/(precision+recall)

    pr_s.append(precision)
    re_s.append(recall)
    f1_s.append(f1)

  return pr_s, re_s, f1_s

Precision, Recall, F1 = Precision_Recall(matrix)

plt.plot(Recall,Precision,'-r',label="CAE")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Recall-Precision curve")
plt.legend(loc='upper right')
plt.grid()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: RuntimeWarning: invalid value encountered in double_scalars

# %%
# f1_score_function
f1_max = max(F1)
print("f1_max = ", round(f1_max,4))
# Out:
# f1_max =  0.0083

# %%
import tensorflow as tf
from keras.models import save_model, load_model
encoder.save('./place_recognition/encoder.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# matrix 저장하기
import numpy as np
np.save('./place_recognition/similarity_matrix_test.npy',matrix)
